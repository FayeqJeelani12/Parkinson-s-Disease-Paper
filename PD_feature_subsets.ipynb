# %%
#loading dataset 
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
df = pd.read_csv("pd_speech_features_1.csv")
df.head(756)
whole_dataset()
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0      0       1  0.85247  0.71826  0.57227        240               239
# 1      0       1  0.76686  0.69481  0.53966        234               233
# 2      0       1  0.85083  0.67604  0.58982        232               231
# 3      1       0  0.41121  0.79672  0.59257        178               177
# 4      1       0  0.32790  0.79782  0.53028        236               235
# 5      1       0  0.50780  0.78744  0.65451        226               221
# 6      2       1  0.76095  0.62145  0.54543        322               321
# 7      2       1  0.83671  0.62079  0.51179        318               317
# 8      2       1  0.80826  0.61766  0.50447        318               317
# 9      3       0  0.85302  0.62247  0.54855        493               492
# 10     3       0  0.80657  0.67256  0.61745        488               487
# 11     3       0  0.82653  0.58326  0.44555        498               497
# ...

# %%
df.to_csv(r'C:\Data\whole_dataset.csv')

# %%
df.shape
# Out:
# (756, 755)

# %%
baseline_f = df.iloc[0:756, 2:23]

# %%
baseline_f
# Out:
#          PPE      DFA     RPDE  numPulses  numPeriodsPulses  meanPeriodPulses  \
# 0    0.85247  0.71826  0.57227        240               239          0.008064
# 1    0.76686  0.69481  0.53966        234               233          0.008258
# 2    0.85083  0.67604  0.58982        232               231          0.008340
# 3    0.41121  0.79672  0.59257        178               177          0.010858
# 4    0.32790  0.79782  0.53028        236               235          0.008162
# 5    0.50780  0.78744  0.65451        226               221          0.007631
# 6    0.76095  0.62145  0.54543        322               321          0.005991
# 7    0.83671  0.62079  0.51179        318               317          0.006074
# 8    0.80826  0.61766  0.50447        318               317          0.006057
# 9    0.85302  0.62247  0.54855        493               492          0.003910
# 10   0.80657  0.67256  0.61745        488               487          0.003956
# ...

# %%
baseline_f.to_csv(r'C:\Data\baseline_features.csv')

# %%
intensity_f = df.iloc[0:756, 23:26]

# %%
intensity_f
# Out:
#      minIntensity  maxIntensity  meanIntensity
# 0       69.997496     76.088046      72.465512
# 1       67.415903     73.046374      71.528945
# 2       62.661706     71.633549      68.086583
# 3       76.306989     81.000749      79.190593
# 4       76.645686     80.937258      79.183495
# 5       74.084566     80.614592      78.732944
# 6       75.059718     78.381263      77.077102
# 7       75.097654     78.465346      76.841929
# 8       75.189839     78.217873      76.974052
# 9       71.256618     80.032378      76.086098
# 10      68.126358     77.901923      74.823313
# 11      73.299601     78.665244      75.994541
# 12      56.587773     63.589097      60.778281
# 13      60.234865     65.611694      63.289551
# 14      55.485019     67.106128      63.215345
# 15      80.937396     83.090509      82.242417
# 16      80.444642     83.861847      82.029744
# 17      80.770342     83.474205      82.240186
# 18      76.616549     80.881080      79.241037
# ...

# %%
intensity_f.to_csv(r'C:\Data\intensity_features.csv')

# %%
timefreq_f = df.iloc[0:756, 26:34]

# %%
timefreq_f
# Out:
#              f1           f2           f3           f4          b1  \
# 0    539.342735  1031.849040  2447.162183  3655.054806  101.092218
# 1    564.363614  1016.367294  2383.565201  3498.681572   58.465428
# 2    548.444604  1032.406341  2357.826954  3678.128717  160.387771
# 3    819.529588  1201.813897  3154.035654  4122.163933  238.667052
# 4    846.796144  1215.346469  3201.513132  4085.456839  402.216738
# 5    832.437252  1193.223486  3177.289013  3791.213621  238.834750
# 6    710.861860  1165.801015  3049.357722  4211.727619  102.075203
# 7    668.306515  1165.769341  2954.648489  3560.280084  128.235259
# 8    670.639344  1127.450888  2933.208331  3833.298076  137.800940
# 9    707.815533  1285.508031  2020.531841  3238.976356  175.856887
# 10   677.225376  1247.116884  1963.760890  3229.710859  121.229172
# 11   751.686472  1285.817993  2186.277217  3140.663975   22.383654
# 12   493.187329  1256.570863  2337.449029  3320.689784  760.283532
# ...

# %%
timefreq_f.to_csv(r'C:\Data\time_freq_features.csv')

# %%
vocalfld_f = df.iloc[0:756, 34:56]

# %%
vocalfld_f
# Out:
#      GQ_prc5_95  GQ_std_cycle_open  GQ_std_cycle_closed  GNE_mean   GNE_std  \
# 0       0.77778            11.7245              2.82770   1.17300  0.265120
# 1       0.81250            13.8284              2.89080   1.02210  0.220040
# 2       0.81818            26.9273              2.69750   0.84951  0.157560
# 3       0.98548           139.5744              1.69610   0.83405  0.172950
# 4       0.97847           102.0549             15.40450   0.83556  0.162100
# 5       0.73122           104.2897             37.56020   0.85470  0.227640
# 6       1.00000            12.0759              0.00000   0.87505  0.099406
# 7       1.00000             9.1775              0.00000   0.83430  0.077763
# 8       1.00000             5.9031              0.00000   0.79163  0.062666
# 9       1.00000             4.8523              0.00000   1.53530  0.243820
# 10      1.00000            15.1116              0.00000   1.80620  0.590620
# ...

# %%
vocalfld_f.to_csv(r'C:\Data\vocal_fold_features.csv')

# %%
mfcc_f = df.iloc[0:756, 56:140]

# %%
mfcc_f
# Out:
#      mean_Log_energy  mean_MFCC_0th_coef  mean_MFCC_1st_coef  \
# 0             9.1817             11.4283              8.4781
# 1             9.6074             12.1387              8.5008
# 2             9.0512             11.3956              7.6362
# 3             9.8453             13.7399              6.7365
# 4            10.1542             14.7643              6.4634
# 5             9.8020             13.8952              6.7310
# 6             9.8604             16.8423              4.9305
# 7             9.9129             16.1057              6.8758
# 8             9.9090             16.7174              6.4642
# 9             9.4496             12.1136              6.7840
# 10            9.7666             12.9138              6.9275
# 11            9.7855             11.8357              6.5105
# 12            9.5537             15.6995              4.2309
# 13            9.3380             14.4753              4.7262
# ...

# %%
mfcc_f.to_csv(r'C:\Data\mfcc_features.csv')

# %%
wavelet_f = df.iloc[0:756, 140:322]

# %%
wavelet_f
# Out:
#            Ea     Ed_1_coef     Ed_2_coef  Ed_3_coef  Ed_4_coef  Ed_5_coef  \
# 0     99.9996  1.530000e-07  8.860000e-07   0.000007   0.000021   0.000102
# 1     99.9998  1.680000e-07  1.230000e-06   0.000012   0.000031   0.000046
# 2     99.9999  1.170000e-07  9.450000e-07   0.000010   0.000034   0.000024
# 3     99.0823  8.545600e-03  2.058600e-02   0.025449   0.041488   0.062341
# 4     98.6930  7.861100e-03  1.123800e-02   0.014564   0.055365   0.030612
# 5     99.5213  1.149600e-02  1.640800e-02   0.026368   0.110000   0.052605
# 6     99.9936  5.140000e-07  7.200000e-06   0.000015   0.000165   0.000061
# 7     99.9954  4.880000e-07  5.600000e-06   0.000047   0.000461   0.000193
# 8     99.9990  3.160000e-07  3.410000e-06   0.000022   0.000073   0.000037
# 9     99.9991  4.690000e-07  2.170000e-06   0.000004   0.000126   0.000048
# 10    99.9994  5.630000e-07  3.360000e-06   0.000016   0.000138   0.000045
# ...

# %%
wavelet_f.to_csv(r'C:\Data\wavelet_trfm_features.csv')

# %%
tqwt_f = df.iloc[0:756, 322:754]

# %%
tqwt_f
# Out:
#      tqwt_energy_dec_1  tqwt_energy_dec_2  tqwt_energy_dec_3  \
# 0             0.000011           0.000004           0.000005
# 1             0.000028           0.000010           0.000011
# 2             0.000034           0.000010           0.000008
# 3             0.000051           0.000041           0.000041
# 4             0.000044           0.000050           0.000061
# 5             0.000040           0.000052           0.000053
# 6             0.000080           0.000098           0.000292
# 7             0.000103           0.000072           0.000117
# 8             0.000044           0.000063           0.000096
# 9             0.000014           0.000018           0.000023
# 10            0.000019           0.000039           0.000077
# 11            0.000017           0.000018           0.000030
# 12            0.000646           0.000323           0.000541
# 13            0.000264           0.000424           0.000970
# ...

# %%
tqwt_f.to_csv(r'C:\Data\tqwt_features.csv')
